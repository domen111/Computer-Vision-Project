# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
no = 4
l = cv.imread(f'images/1206/img{no:04d}l.png')
r = cv.imread(f'images/1206/img{no:04d}r.png')
d = cv.imread(f'images/1206/img{no:04d}disparity.png')

# %%
d = cv.resize(d, (r.shape[1], r.shape[0]))
# d = d[:, 512:]

# %%
# plt.imshow(r)

# %%
plt.imshow(d)

# %%
plt.imshow(l)

# %%
# plt.imshow(d[:, 512:])

# %%
# plt.imshow(r[:, :-512])

# %%
# plt.imshow(((d[:, 512:].astype(float) + r[:, :-512].astype(float)) / 2).astype('uint8'))

# %%
plt.imshow(((d.astype(float) + l.astype(float)) / 2).astype('uint8'))
